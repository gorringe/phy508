# %%
n = int( input("enter integer "))
# Out:
# enter integer 1000

# %%
factor = 1

while factor <= n:
    if (n % factor == 0):
        print("factor", factor)
    factor = factor + 1
# Out:
# factor 1
# factor 2
# factor 4
# factor 5
# factor 8
# factor 10
# factor 20
# factor 25
# factor 40
# factor 50
# factor 100
# factor 125
# factor 200
# factor 250
# factor 500
# factor 1000
