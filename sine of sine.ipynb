# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-2*np.pi, 2*np.pi, 1000)
y1 = np.sin(x)
y2 = np.sin(np.sin(x))

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('x')
plt.ylabel('sin(sin(x))')
plt.title('Plot of sin(sin(x))')
plt.show()
