# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
M = 40          # grid size MxM
V = 1.0         # top wall Vo
target = 1e-4   # accuracy

phi = np.zeros([M+1,M+1],float)      # previous iteration
phiprime = np.empty([M+1,M+1],float) # current interation

# %%
delta = 1.0 # iteration dV

while delta > target:

    for i in range(M):
        for j in range(M):

            if i == 10 and j > 10 and j < 30: # boundary condition left plate
                phiprime[i,j] = +V
            elif i == 30 and j > 10 and j < 30: # boundary condition right plate
                 phiprime[i,j] = -V
            else:
                phiprime[i,j] = (phi[i+1,j] + phi[i-1,j] + phi[i,j+1] + phi[i,j-1])/4

    delta = np.max(abs(phi-phiprime))       # iteration max difference
    phi,phiprime = phiprime,phi
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-cf9df72b199d> in <cell line: 3>()
#       6         for j in range(M):
#       7
# ----> 8             if i == 10 and j > 10 and j < 30: # boundary condition left plate
#       9                 phiprime[i,j] = +V
#      10             elif i == 30 and j > 10 and j < 30: # boundary condition right plate
#
# KeyboardInterrupt:

# %%
plt.imshow(phi)

# %%
np.shape(phi)

# %%
plt.plot(phi[:,5])
plt.ylabel("fringe field at i=5")
plt.xlabel("vertical position")

# %%
plt.plot(phi[:,20])
