# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return 4*x**2+1

def fprime(x):
    return 8*x

x0 = 3.0
maxevals = 100
tolerance = 1e-6

# Lists to store the iteration history
xi = [x0]
fi = [f(x0)]

# Gauss-Newton optimization loop
for i in range(maxevals):
    xi[i+1] = xi[i] - f(xi[i]) / fprime(xi[i]) # G-N eqn
    x_values.append(x_next)
    f_values.append(f(x_next))

    # Check for convergence
    if abs(x_next - x_current) < tolerance:
        break

# Print the result
minimum_x = x_values[-1]
minimum_f = f_values[-1]
print(f"Minimum at x = {minimum_x}, f(x) = {minimum_f}")

# Plot the function and the optimization path
x_range = np.linspace(min(x_values) - 1, max(x_values) + 1, 100)
plt.plot(x_range, f(x_range), label='f(x)')
plt.plot(x_values, f_values, 'ro-', label='Gauss-Newton Path')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid()
plt.show()
# Out:
# 0 3.0 37.0
# 1 1.4583333333333333 9.506944444444443
# 2 0.643452380952381 2.656123866213152
# 3 0.12746162063345234 1.0649858589380246
# 4 -0.9169565477976717 4.363237242196095
# 5 -0.32215774671548936 1.4151424550752056
# 6 0.22692980026385412 1.205988536991171
# 7 -0.43736623731525237 1.7651569021732065
# 8 0.0671185489957925 1.0180195984772025
# 9 -1.8288171008888234 14.378287954013604
# 10 -0.8460583584327289 3.863258983495536
# 11 -0.27528523371412417 1.30312783960416
# 12 0.3164318655026017 1.4005165020218264
# 13 -0.23681381496850407 1.2243231318397476
# 14 0.4094339197775564 1.670544538657658
# 15 -0.10058261096239107 1.040467446512047
# 16 1.1924682411638887 6.687922024737993
# 17 0.4914095259428487 1.9659332887495011
# 18 -0.0086655603554735 1.0003003677450975
# 19 14.420585502348011 832.8131449221186
# 20 7.2016245871816595 208.45358677879764
# 21 3.58345509890694 52.364601783528585
# 22 1.756845013869829 13.34601761103712
# 23 0.8072722352756857 3.606753847388008
# ...
