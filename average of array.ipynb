# %%
import numpy as np

# %%
#x = np.array([9.8,9.9,9.6,9.8],float)
from google.colab import drive
drive.mount("/content/drive")
x = np.loadtxt("/content/drive/My Drive/Courses/phy508/measurements.txt")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
x.dtype # type of array variables
x.shape # lengths of array dimensions
print(x)
# Out:
# [9.8 9.9 9.6 9.9]

# %%
avg = sum(x)/len(x)

# %%
var = sum( (x-avg)**2 ) / (len(x) - 1)

# %%
print("data", x, "min", min(x), "max", max(x), "avg", avg, "var", var)
# Out:
# data [9.8 9.9 9.6 9.9] min 9.6 max 9.9 avg 9.8 var 0.02000000000000009
