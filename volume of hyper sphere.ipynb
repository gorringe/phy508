# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
N = 1000000 # number of random points in 1x1x1 cube
count = 0 # number of ransom points in hemisphere
vp, xp, yp, zp = [], [], [], []
vps, xps, yps, zps = [], [], [], []

# %%
for j in range(N):
    v,x,y,z =  np.random.ranf(), np.random.ranf(),  np.random.ranf(),  np.random.ranf()
    if v**2 + x**2 + y**2 + z**2 < 1:
        count += 1

# %%
nvol = 2**4 * float(count) / float(N) 
avol = np.pi*np.pi/2. # π^2R^4/2 
print("numerical volume = ",nvol,"analytical volume = ",avol)
# Out:
# numerical volume =  4.947744 analytical volume =  4.934802200544679
