# %%
import numpy as np

# %%
#precision loss in large floats
a = 1e20
b = 1
c = a + b
print(c)  # 1e+20 not 1e+20 + 1
# Out:
# 1e+20

# %%
# comparing two floats
a = 0.1 + 0.2
b = 0.3
print( a, b, a == b)
# Out:
# 0.30000000000000004 0.3 False

# %%
# difference of large floats
x = 1e-15
y = 1.0
z = (x + y) - y
print(z)
# Out:
# 1.1102230246251565e-15
