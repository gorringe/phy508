# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/drive")
data = np.loadtxt("/content/drive/My Drive/Courses/phy508/stars.txt")
# Out:
# Mounted at /content/drive

# %%
data.shape, data.size
# Out:
# ((7860, 2), 15720)

# %%
luminosity = data[:,0]
color = data[:,1]
color.shape
# Out:
# (7860,)

# %%
plt.scatter(color,luminosity,c="r", marker=".")
plt.ylim(0,12000)
plt.xlim(-5,20)
plt.title("Hertzsprung-Russell diagram")
plt.xlabel("color (temp)")
plt.ylabel("luminosity")
# Out:
# Text(0, 0.5, 'luminosity')
