# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_data=pd.read_csv('/content/drive/MyDrive/Courses/phy508/stars.csv')
data = df_data.to_numpy()

# %%
data.shape, data.size
# Out:
# ((7859, 2), 15718)

# %%
magnitude = data[:,1]
temperature = data[:,0]

# %%
plt.scatter(temperature,magnitude,color='r',marker='.')
plt.xlim(0,12000)
plt.ylim(20,-5)
# Out:
# (20.0, -5.0)
