# %%
import numpy as np

# %%
g = 9.8

# %%
y = float( input("distance fallen (meters)") )
# Out:
# distance fallen (meters)30.0

# %%
t = np.sqrt(2*y/g)

# %%
print("time taken (seconds) ", t)
# Out:
# time taken (seconds)  2.4743582965269675
