# %%
fib1 = 0
fib2 = 1
i = 0
print('  n    Fibonacci')
while (fib1 < 1000):
  print("  ", i, "  ", fib1)
  temp = fib1
  fib1 = fib2
  fib2 = temp+fib2
  i += 1
# Out:
#   n    Fibonacci
#    0    0
#    1    1
#    2    1
#    3    2
#    4    3
#    5    5
#    6    8
#    7    13
#    8    21
#    9    34
#    10    55
#    11    89
#    12    144
#    13    233
#    14    377
#    15    610
#    16    987
