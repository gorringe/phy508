# %%
import numpy as np

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
x = np.loadtxt("/content/drive/MyDrive/Courses/phy508/measurements.txt")
x.shape()

# %%
avg = sum(x)/len(x)
var = sum( (x-avg)**2 ) / (len(x) - 1)
print("data", x, "min", min(x), "max", max(x), "avg", avg, "sgma", var)
# Out:
# data [9.8 9.9 9.6 9.9] min 9.6 max 9.9 avg 9.8 sgma 0.02000000000000009

# %%
rtn = np.savetxt("/content/drive/MyDrive/Courses/phy508/measurements-copy.txt", x, delimiter=',', fmt='%d')
print(rtn)
# Out:
# None
